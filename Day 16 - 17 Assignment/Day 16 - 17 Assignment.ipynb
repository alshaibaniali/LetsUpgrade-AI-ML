# %% [markdown]
# # Assignment Day 16-17

# %% [markdown]
# Ali Mohammed Taresh Ali
#
# ali713626792@gmail.com

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border-style: solid;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border-style: solid;
# }

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
titles = pd.read_csv('C:/Users/(pandas 1)/Day 16 - 17 Assingment/Dataset for Pandas Assinment/titles.csv')
print(titles.shape)
titles.head()
# Out:
# (244914, 2)
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %%
cast = pd.read_csv('C:/Users/(pandas 1)/Day 16 - 17 Assingment/Dataset for Pandas Assinment/cast.csv')
print(cast.shape)
cast.head()
# Out:
# (3786176, 6)
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(titles)
# Out:
# 244914

# %%
titles.count()
# Out:
# title    244914
# year     244914
# dtype: int64

# %% [markdown]
# There are 244914 movies listed in the titles dataframe.

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 193222          Miss Jerry  1894
# 51388   The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
len(titles[titles.title == 'Hamlet'])
# Out:
# 20

# %%
titles[titles['title'] == "Hamlet"].title.count()
# Out:
# 20

# %% [markdown]
# There are 20 movies have a title "Hamlet" in dataset.

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(titles[titles.title == "North by Northwest"])
# Out:
# 1

# %% [markdown]
# There is 1 movie have a title "North by Northwest" in dataset.

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles.title == "Hamlet"].sort_values('year').head(1)
# Out:
#         title  year
# 52521  Hamlet  1910

# %% [markdown]
# In 1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles.title == "Treasure Island"].sort_values('year')
# Out:
#                   title  year
# 55686   Treasure Island  1918
# 196514  Treasure Island  1920
# 141822  Treasure Island  1934
# 77354   Treasure Island  1950
# 65051   Treasure Island  1972
# 37238   Treasure Island  1973
# 173051  Treasure Island  1985
# 27076   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
titles[titles['year'] == 1950].year.count()
# Out:
# 1113

# %% [markdown]
# There are 1,113 movies made in year 1950.

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
titles[titles['year'] == 1960].year.count()
# Out:
# 1549

# %% [markdown]
# There are 1,549 movies made in year 1960.

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
tm = 0
for i in range(1950, 1960):
    tm += titles[titles['year'] == i].count().year
print(tm)
# Out:
# 12934

# %%
titles[(titles['year']>=1950) & (titles['year']<=1959)].year.count()
# Out:
# 12934

# %% [markdown]
# 12,934 movies made from 1950 through 1959.

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles.title == "Batman"]
# Out:
#          title  year
# 39349   Batman  1943
# 240896  Batman  1989

# %% [markdown]
# In 1943 and 1989 movie Batman has been released.

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast
# Out:
#                                     title  year                         name  \
# 0                          Closet Monster  2015                     Buffy #1
# 1                         Suuri illusioni  1985                       Homo $
# 2                     Battle of the Sexes  2017                      $hutter
# 3                    Secret in Their Eyes  2015                      $hutter
# 4                              Steve Jobs  2015                      $hutter
# ...                                   ...   ...                          ...
# 3786171                           Foxtrot  1988            Lilja ??risd?ttir
# 3786172  Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3786173                         Skammdegi  1985           Dalla ??r?ard?ttir
# 3786174                      U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3786175                 Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
# ...

# %%
cast[cast['title']=='Inception'].character.shape[0]
# Out:
# 78

# %%
cast[cast['title']=='Inception'].character.count()
# Out:
# 78

# %% [markdown]
# There are 78 roles were there in the movie "Inception".

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast[cast['title']=='Inception'].isnull().sum().sum()
# Out:
# 27

# %% [markdown]
# There are 27 roles in the movie "Inception" are NOT ranked by an "n" value.

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
Inception_Films = cast[cast.title == 'Inception'].notna().n.sum()
Inception_Films
# Out:
# 51

# %% [markdown]
# 51 roles in the movie "Inception" receive an "n" value.

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
North_By_NorthWest_Films = cast[cast.title == "North by Northwest"]

# %%
North_By_NorthWest_Films[North_By_NorthWest_Films.n.notna()].sort_values('n')
# Out:
#                       title  year                  name     type  \
# 871426   North by Northwest  1959            Cary Grant    actor
# 3518333  North by Northwest  1959       Eva Marie Saint  actress
# 1457165  North by Northwest  1959           James Mason    actor
# 3157232  North by Northwest  1959   Jessie Royce Landis  actress
# 356707   North by Northwest  1959        Leo G. Carroll    actor
# 3048272  North by Northwest  1959  Josephine Hutchinson  actress
# 1695173  North by Northwest  1959           Philip Ober    actor
# 1275337  North by Northwest  1959         Martin Landau    actor
# 2447081  North by Northwest  1959         Adam Williams    actor
# 1811387  North by Northwest  1959          Edward Platt    actor
# 665768   North by Northwest  1959     Robert Ellenstein    actor
# 2295714  North by Northwest  1959          Les Tremayne    actor
# 464736   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
Sleuth = cast[cast.title == 'Sleuth']
Sleuth_1972 = Sleuth[Sleuth.year == 1972].sort_values('n')
print('The entire cast, in "n"-order, of the 1972 film "Sleuth":')
Sleuth_1972
# Out:
# The entire cast, in "n"-order, of the 1972 film "Sleuth":
#           title  year                name     type  \
# 1705394  Sleuth  1972    Laurence Olivier    actor
# 326773   Sleuth  1972       Michael Caine    actor
# 373876   Sleuth  1972      Alec Cawthorne    actor
# 1465483  Sleuth  1972  John (II) Matthews    actor
# 2724553  Sleuth  1972  Eve (III) Channing  actress
# 1448690  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1705394                 Andrew Wyke  1.0
# 326773                  Milo Tindle  2.0
# 373876            Inspector Doppler  3.0
# 1465483  Detective Sergeant Tarrant  4.0
# 2724553             Marguerite Wyke  5.0
# 1448690      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
Sleuth_2007 = Sleuth[Sleuth.year == 2007].sort_values('n')
Sleuth_2007
# Out:
#           title  year                 name     type          character    n
# 326774   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1293634  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1805907  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 260242   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 373877   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2724552  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3370424  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast['title']=='Hamlet') & (cast['year']==1921)].character.shape[0]
# Out:
# 9

# %%
cast[(cast['title']=='Hamlet') & (cast['year']==1921)].character.count()
# Out:
# 9

# %% [markdown]
# 9 roles were credited in the silent 1921 version of Hamlet

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast[(cast['title']=='Hamlet') & (cast['year']==1996)].character.shape[0]
# Out:
# 54

# %% [markdown]
# 54 roles were credited in Branagh’s 1996 Hamlet

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast[cast['title']=='Hamlet'].character.shape[0]
# Out:
# 342

# %% [markdown]
# 342 "Hamlet" roles have been listed in all film credits through history.

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast[cast.character == "Ophelia"].name.count()
# Out:
# 117

# %% [markdown]
# 117 people have played an "Ophelia".

# %%
cast[cast.character == "Ophelia"].name.drop_duplicates().count()
# Out:
# 115

# %% [markdown]
# 115 people without duplicates have played an "Ophelia".

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast.character == "The Dude"].name.count()
# Out:
# 19

# %% [markdown]
# 19 people have played a role called "The Dude"

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast.character == "The Stranger"].name.count()
# Out:
# 212

# %% [markdown]
# 212 people with duplicates have played a role called "The Stranger".

# %%
cast[cast.character == "The Stranger"].name.drop_duplicates().count()
# Out:
# 202

# %% [markdown]
# 202 people without duplicates have played a role called "The Stranger".

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[cast.name == "Sidney Poitier"].name.count()
# Out:
# 43

# %%
cast[cast.name == "Sidney Poitier"].character.count()
# Out:
# 43

# %% [markdown]
# Sidney Poitier has played 43 roles throughout his career.

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast.name == "Judi Dench"].name.count()
# Out:
# 55

# %% [markdown]
# Judi Dench has played 55 roles throughout his career.

# %%
cast[cast.name == "Judi Dench"].character.drop_duplicates().count()
# Out:
# 46

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast['name'] == 'Cary Grant') & (cast['n'] == 2) & (cast['year'] < 1950) & (cast['year'] >= 1940)].sort_values(by='year')
# Out:
#                    title  year        name   type    character    n
# 871423  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 871433    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast['name'] == 'Cary Grant') & (cast['n'] == 1) & (cast['year'] < 1950) & (cast['year'] >= 1940)].sort_values(by='year')
# Out:
#                                        title  year        name   type  \
# 871448               The Howards of Virginia  1940  Cary Grant  actor
# 871407                       His Girl Friday  1940  Cary Grant  actor
# 871450                The Philadelphia Story  1940  Cary Grant  actor
# 871438                             Suspicion  1941  Cary Grant  actor
# 871452                  The Talk of the Town  1942  Cary Grant  actor
# 871429                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 871398                     Destination Tokyo  1943  Cary Grant  actor
# 871422                             Mr. Lucky  1943  Cary Grant  actor
# 871430                      Once Upon a Time  1944  Cary Grant  actor
# 871390                  Arsenic and Old Lace  1944  Cary Grant  actor
# 871425             None But the Lonely Heart  1944  Cary Grant  actor
# 871424                         Night and Day  1946  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[(cast['year'] >= 1950) & (cast['year'] < 1960) & (cast['type'] == 'actor')]['character'].count()
# Out:
# 157738

# %% [markdown]
# 157,738 roles were available for actors in the 1950s

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
cast[(cast['year'] >= 1950) & (cast['year'] < 1960) & (cast['type'] == 'actress')]['character'].count()
# Out:
# 57733

# %% [markdown]
# There are 57,733 roles available for actresses in 1950's.

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast[(cast['year'] >= 1894) & (cast['year'] <= 1980) & (cast['n'] == 1)]['character'].count()
# Out:
# 65140

# %% [markdown]
# 65,140 leading roles were available from the beginning of film history through 1980

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
cast[(cast['year'] >= 1894) & (cast['year'] <= 1980) & (cast['n'] > 1)]['character'].count()
# Out:
# 669320

# %% [markdown]
# 669,320 non-leading roles were available through from the beginning of film history through 1980.

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
cast[(cast['year'] >= 1894) & (cast['year'] <= 1980)]['n'].isnull().sum()
# Out:
# 448347

# %% [markdown]
# 448,347 roles through 1980 were minor enough that they did not warrant a numeric "n" rank.

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\unkno\\Desktop\\LetsUpgrade\\LetsUpgrade AI and ML\\Day 17  Exploratory Data Analytics _4(pandas 2)\\Day 16 - 17 Assingment\\Day 16 - 17 Assignment'
